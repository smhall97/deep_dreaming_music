# %% [markdown]
# <a href="https://colab.research.google.com/github/smhall97/hallucinating_GANs/blob/main/CNN_finetuning_stft_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Imports

import os
import glob
#import imageio
#import random, shutil
import torch
#import gc
#import csv
#import multiprocessing
#import requests
import time
import copy
#import librosa
#import librosa.display

#import pandas as pd
import numpy as np
#import cv2 as cv
import matplotlib.pyplot as plt
#import IPython.display as display
import pickle
from tqdm.notebook import tqdm



import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.optim import lr_scheduler

# %%
# @title Set Device

def set_device():
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
      print("WARNING: For this notebook to perform best, "
          "if possible, in the menu under `Runtime` -> "
          "`Change runtime type.`  select `GPU` ")
  else:
      print("GPU is enabled in this notebook.")

  return device

# %%
# @title Mount Google Drive

from google.colab import drive
drive.mount('/content/drive') #it will ask you for a verification code
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title some functions

def scale_minmax(X):

    X_scaled = (X - X.min()) / (X.max() - X.min())

    return X_scaled


def pickle_loader_mel(file):
  with open(file, 'rb') as f:
      data = pickle.load(f)
      data = np.transpose(data, axes=[1, 2, 0])
      data = scale_minmax(data)

      zeros = np.zeros(data.shape)

      data = np.concatenate((data, zeros, zeros), axis=2)

  return(data)


def pickle_loader_stft(file):
  with open(file, 'rb') as f:
      data = pickle.load(f)
      data = np.squeeze(data, axis=0)

      #real and imaginary parts are scaled independently
      data[:,:,0] = scale_minmax(data[:,:,0])
      data[:,:,1] = scale_minmax(data[:,:,1])

      real = data[:,:,0].unsqueeze(2)

      zeros = np.zeros((data.shape[0],data.shape[1],1))
      data = np.concatenate((real, real, real), axis=2)

  return(data)


def make_sets(classes, items_per_class, ratios):
  """
  parameters:
  classes: number of classes in dataset
  items_per_class: elements per class (assumes that the dataset is balanced across classes)
  ratios: list or array with ratios for each subset [ratio_trainining, ratio_validation, ratio_test]
  """

  train_size = ratios[0] * items_per_class
  val_size = ratios[1] * items_per_class
  test_size = ratios[2] * items_per_class

  test_ix, val_ix, train_ix = np.array([]),np.array([]),np.array([])

  for i in range(classes): 
    class_ix = items_per_class * i
    
    train_ix = np.append(train_ix, np.arange(train_size) + class_ix)
    val_ix = np.append(val_ix, np.arange(train_size, train_size + val_size) + class_ix)
    test_ix = np.append(test_ix, np.arange(train_size + val_size, train_size + val_size + test_size) + class_ix)

  return train_ix.astype(int), val_ix.astype(int), test_ix.astype(int)

# %%
# @title Paths and script parameters

dummy_mode = True

path = '/content/drive/MyDrive/HallucinatingGANs/Code/data/'

transform = 'stft'

n_fft = 1024
n_mels = 128
hop_length = 256 # smaller hop size leads to better reconstruction but takes longer to compute
power = 2.0 # squared power spectrogram
samplerate =  22050

def get_cfg_transform(t):
  if t == 'stft':
    params = '{}_{}'.format(str(n_fft), str(hop_length))
    pickle_loader = pickle_loader_stft
    dims = (513, 2580)
  
  elif t == 'mel':
    params = '{}_{}_{}'.format(str(n_fft), str(hop_length), n_mels)
    pickle_loader = pickle_loader_mel
    dims = (128, 2580)
  return params, pickle_loader, dims

#if dummy_mode:

# %%
params, pickle_loader, dims = get_cfg_transform(transform)

data_dir = os.path.join(os.path.abspath(path), 'spectrograms', transform, params)
print(data_dir)

data_transforms = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.CenterCrop(dims),
                                      transforms.Resize((128, 1290)), #here i just downsample bc colab cannot handle the big version (out-of-memory crash)
                                      transforms.Normalize(mean=[.5,.5,.5], std=[.5,.5,.5])
                                      ])

dataset = torchvision.datasets.DatasetFolder(root=data_dir,
                                             transform = data_transforms, 
                                             loader=pickle_loader, 
                                             extensions='.pkl', 
                                             )

genres = list(os.listdir(data_dir))
n_classes = len(genres) 

train_ix, val_ix, test_ix = make_sets(n_classes, 100, [.8, .1, .1])

subsets = {
          'train': torch.utils.data.Subset(dataset, train_ix),
          'val': torch.utils.data.Subset(dataset, val_ix)
          }

dataloaders = {x: torch.utils.data.DataLoader(subsets[x], batch_size=25,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}

dataset_sizes = {x: len(dataloaders[x].dataset) for x in ['train', 'val']}
print(dataset_sizes)
# Out:
# /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/stft/1024_256
# {'train': 800, 'val': 100}
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
#dataset[0][0].shape
print(dataset[0][0].shape, dataset[0][0].dtype)
print(dataset)
print(torch.min(dataset[0][0]))
print(torch.max(dataset[0][0]))
print(torch.mean(dataset[0][0]))
print(torch.std(dataset[0][0]))
#print(dataset[0][0][1])
#print(dataset[0][0][2])
# Out:
# torch.Size([3, 128, 1290]) torch.float32
# Dataset DatasetFolder
#     Number of datapoints: 1000
#     Root location: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/stft/1024_256
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                CenterCrop(size=(513, 2580))
#                Resize(size=(128, 1290), interpolation=bilinear, max_size=None, antialias=None)
#                Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
#            )
# tensor(-0.2685)
# tensor(0.0753)
# tensor(-0.0776)
# tensor(0.0052)

# %%
# @title Set device (GPU or CPU)
# NMA code
# inform the user if the notebook uses GPU or CPU.

def set_device():
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
  else:
    print("GPU is enabled in this notebook.")

  return device

device = set_device()
# Out:
# GPU is enabled in this notebook.

# %%
# @title Load pretrained VGG
"""
code extracted from:
https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html#convnet-as-fixed-feature-extractor
https://pytorch.org/vision/stable/models.html

"""

vgg16 = models.vgg16(pretrained=True)

# Freeze the network except the last layer / unfreeze layers to allow finetuning
for param in vgg16.parameters():
    param.requires_grad = True # If True it will train

# Parameters of newly constructed modules have requires_grad=True by default
# Add on classifier

vgg16.classifier[6] = nn.Sequential(
                      nn.Linear(vgg16.classifier[3].in_features, 256),
                      nn.ReLU(), 
                      nn.Linear(256, n_classes),                   
                      nn.LogSoftmax(dim=1))

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(vgg16.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
print(vgg16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=10, bias=True)
#       (3): LogSoftmax(dim=1)
#     )
#   )
# )

# %%
# @title Train model function from PyTorch

# Original code from this tutorial: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_acc_list, val_acc_list = [], []
    # train_loss, validation_loss = [], []
    for epoch in tqdm(range(num_epochs)):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            num_examples = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                num_examples += inputs.size(0)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs.float())
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()
            # Different to tutorial, hardcoded dataset size
            # print(dataset_sizes) from above 
            
            #if phase == 'train':
            #    num_examples = len(train_loader) * len(next(iter(train_loader))[0]) 
            #else:
            #    num_examples = len(val_loader) * len(next(iter(val_loader))[0])
            print('number of examples in loader = ', num_examples)
            print(f'RUNNING LOSS: {running_loss}, RUNNING CORRECTS: {running_corrects}')

            epoch_loss = running_loss / num_examples
            print()
            epoch_acc = running_corrects.double() / num_examples
            if phase == 'train':
              train_acc_list.append(epoch_acc)
            else:
              val_acc_list.append(epoch_acc)
          
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    
    # model = model.to('cuda')
    return model, train_acc_list, val_acc_list

# %%
# model trains - change num_epochs to increase training time
vgg16 = vgg16.float()
model_ft, train_acc_list, val_acc_list = train_model(vgg16.to(device), criterion, optimizer_conv, exp_lr_scheduler,
                       num_epochs=30)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 0/29
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# number of examples in loader =  800
# RUNNING LOSS: 1843.9025223255157, RUNNING CORRECTS: 79
#
# train Loss: 2.3049 Acc: 0.0988
# number of examples in loader =  100
# RUNNING LOSS: 229.85134720802307, RUNNING CORRECTS: 13
#
# val Loss: 2.2985 Acc: 0.1300
#
# Epoch 1/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1836.122465133667, RUNNING CORRECTS: 105
#
# train Loss: 2.2952 Acc: 0.1313
# number of examples in loader =  100
# RUNNING LOSS: 228.22303175926208, RUNNING CORRECTS: 16
#
# val Loss: 2.2822 Acc: 0.1600
#
# Epoch 2/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1811.1313104629517, RUNNING CORRECTS: 164
#
# train Loss: 2.2639 Acc: 0.2050
# number of examples in loader =  100
# RUNNING LOSS: 222.48279452323914, RUNNING CORRECTS: 28
#
# val Loss: 2.2248 Acc: 0.2800
#
# Epoch 3/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1685.1123213768005, RUNNING CORRECTS: 213
#
# train Loss: 2.1064 Acc: 0.2662
# number of examples in loader =  100
# RUNNING LOSS: 193.10899078845978, RUNNING CORRECTS: 30
#
# val Loss: 1.9311 Acc: 0.3000
#
# Epoch 4/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1560.8108431100845, RUNNING CORRECTS: 235
#
# train Loss: 1.9510 Acc: 0.2938
# number of examples in loader =  100
# RUNNING LOSS: 190.2880847454071, RUNNING CORRECTS: 29
#
# val Loss: 1.9029 Acc: 0.2900
#
# Epoch 5/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1468.2940155267715, RUNNING CORRECTS: 268
#
# train Loss: 1.8354 Acc: 0.3350
# number of examples in loader =  100
# RUNNING LOSS: 192.58084893226624, RUNNING CORRECTS: 27
#
# val Loss: 1.9258 Acc: 0.2700
#
# Epoch 6/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1462.94806599617, RUNNING CORRECTS: 254
#
# train Loss: 1.8287 Acc: 0.3175
# number of examples in loader =  100
# RUNNING LOSS: 186.36366724967957, RUNNING CORRECTS: 32
#
# val Loss: 1.8636 Acc: 0.3200
#
# Epoch 7/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1358.780312538147, RUNNING CORRECTS: 296
#
# train Loss: 1.6985 Acc: 0.3700
# number of examples in loader =  100
# RUNNING LOSS: 169.96042728424072, RUNNING CORRECTS: 35
#
# val Loss: 1.6996 Acc: 0.3500
#
# Epoch 8/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1303.7246495485306, RUNNING CORRECTS: 311
#
# train Loss: 1.6297 Acc: 0.3887
# number of examples in loader =  100
# RUNNING LOSS: 168.38024258613586, RUNNING CORRECTS: 40
#
# val Loss: 1.6838 Acc: 0.4000
#
# Epoch 9/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1276.381903886795, RUNNING CORRECTS: 333
#
# train Loss: 1.5955 Acc: 0.4163
# number of examples in loader =  100
# RUNNING LOSS: 167.68324971199036, RUNNING CORRECTS: 39
#
# val Loss: 1.6768 Acc: 0.3900
#
# Epoch 10/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1281.7673295736313, RUNNING CORRECTS: 315
#
# train Loss: 1.6022 Acc: 0.3937
# number of examples in loader =  100
# RUNNING LOSS: 168.43791604042053, RUNNING CORRECTS: 41
#
# val Loss: 1.6844 Acc: 0.4100
#
# Epoch 11/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1265.4030531644821, RUNNING CORRECTS: 330
#
# train Loss: 1.5818 Acc: 0.4125
# number of examples in loader =  100
# RUNNING LOSS: 169.7820782661438, RUNNING CORRECTS: 45
#
# val Loss: 1.6978 Acc: 0.4500
#
# Epoch 12/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1252.6126563549042, RUNNING CORRECTS: 346
#
# train Loss: 1.5658 Acc: 0.4325
# number of examples in loader =  100
# RUNNING LOSS: 168.6326503753662, RUNNING CORRECTS: 44
#
# val Loss: 1.6863 Acc: 0.4400
#
# Epoch 13/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1234.7724735736847, RUNNING CORRECTS: 331
#
# train Loss: 1.5435 Acc: 0.4138
# number of examples in loader =  100
# RUNNING LOSS: 167.019185423851, RUNNING CORRECTS: 46
#
# val Loss: 1.6702 Acc: 0.4600
#
# Epoch 14/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1197.4994659423828, RUNNING CORRECTS: 361
#
# train Loss: 1.4969 Acc: 0.4512
# number of examples in loader =  100
# RUNNING LOSS: 165.56085348129272, RUNNING CORRECTS: 44
#
# val Loss: 1.6556 Acc: 0.4400
#
# Epoch 15/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1207.9452455043793, RUNNING CORRECTS: 340
#
# train Loss: 1.5099 Acc: 0.4250
# number of examples in loader =  100
# RUNNING LOSS: 165.27381539344788, RUNNING CORRECTS: 43
#
# val Loss: 1.6527 Acc: 0.4300
#
# Epoch 16/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1200.7784694433212, RUNNING CORRECTS: 352
#
# train Loss: 1.5010 Acc: 0.4400
# number of examples in loader =  100
# RUNNING LOSS: 164.5427703857422, RUNNING CORRECTS: 45
#
# val Loss: 1.6454 Acc: 0.4500
#
# Epoch 17/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1196.439853310585, RUNNING CORRECTS: 354
#
# train Loss: 1.4955 Acc: 0.4425
# number of examples in loader =  100
# RUNNING LOSS: 165.3676599264145, RUNNING CORRECTS: 44
#
# val Loss: 1.6537 Acc: 0.4400
#
# Epoch 18/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1185.9750658273697, RUNNING CORRECTS: 360
#
# train Loss: 1.4825 Acc: 0.4500
# number of examples in loader =  100
# RUNNING LOSS: 164.96178805828094, RUNNING CORRECTS: 43
#
# val Loss: 1.6496 Acc: 0.4300
#
# Epoch 19/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1196.258482336998, RUNNING CORRECTS: 344
#
# train Loss: 1.4953 Acc: 0.4300
# number of examples in loader =  100
# RUNNING LOSS: 164.58007395267487, RUNNING CORRECTS: 45
#
# val Loss: 1.6458 Acc: 0.4500
#
# Epoch 20/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1180.0527602434158, RUNNING CORRECTS: 364
#
# train Loss: 1.4751 Acc: 0.4550
# number of examples in loader =  100
# RUNNING LOSS: 164.7270381450653, RUNNING CORRECTS: 45
#
# val Loss: 1.6473 Acc: 0.4500
#
# Epoch 21/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1185.1889729499817, RUNNING CORRECTS: 338
#
# train Loss: 1.4815 Acc: 0.4225
# number of examples in loader =  100
# RUNNING LOSS: 164.77720737457275, RUNNING CORRECTS: 45
#
# val Loss: 1.6478 Acc: 0.4500
#
# Epoch 22/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1194.7087615728378, RUNNING CORRECTS: 342
#
# train Loss: 1.4934 Acc: 0.4275
# number of examples in loader =  100
# RUNNING LOSS: 164.8166060447693, RUNNING CORRECTS: 45
#
# val Loss: 1.6482 Acc: 0.4500
#
# Epoch 23/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1183.9724659919739, RUNNING CORRECTS: 362
#
# train Loss: 1.4800 Acc: 0.4525
# number of examples in loader =  100
# RUNNING LOSS: 164.64856266975403, RUNNING CORRECTS: 46
#
# val Loss: 1.6465 Acc: 0.4600
#
# Epoch 24/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1186.3386809825897, RUNNING CORRECTS: 360
#
# train Loss: 1.4829 Acc: 0.4500
# number of examples in loader =  100
# RUNNING LOSS: 164.72663283348083, RUNNING CORRECTS: 46
#
# val Loss: 1.6473 Acc: 0.4600
#
# Epoch 25/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1185.7109010219574, RUNNING CORRECTS: 357
#
# train Loss: 1.4821 Acc: 0.4463
# number of examples in loader =  100
# RUNNING LOSS: 164.6760195493698, RUNNING CORRECTS: 47
#
# val Loss: 1.6468 Acc: 0.4700
#
# Epoch 26/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1182.7940165996552, RUNNING CORRECTS: 358
#
# train Loss: 1.4785 Acc: 0.4475
# number of examples in loader =  100
# RUNNING LOSS: 164.72478806972504, RUNNING CORRECTS: 46
#
# val Loss: 1.6472 Acc: 0.4600
#
# Epoch 27/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1183.3885699510574, RUNNING CORRECTS: 354
#
# train Loss: 1.4792 Acc: 0.4425
# number of examples in loader =  100
# RUNNING LOSS: 164.69702124595642, RUNNING CORRECTS: 47
#
# val Loss: 1.6470 Acc: 0.4700
#
# Epoch 28/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1205.408364534378, RUNNING CORRECTS: 355
#
# train Loss: 1.5068 Acc: 0.4438
# number of examples in loader =  100
# RUNNING LOSS: 164.67664241790771, RUNNING CORRECTS: 47
#
# val Loss: 1.6468 Acc: 0.4700
#
# Epoch 29/29
# ----------
# number of examples in loader =  800
# RUNNING LOSS: 1182.2247236967087, RUNNING CORRECTS: 358
#
# train Loss: 1.4778 Acc: 0.4475
# number of examples in loader =  100
# RUNNING LOSS: 164.6741896867752, RUNNING CORRECTS: 47
#
# val Loss: 1.6467 Acc: 0.4700
#
# Training complete in 88m 3s
# Best val Acc: 0.470000

# %%
import psutil
psutil.virtual_memory().total / (1024.0 ** 3)
# Out:
# 12.686656951904297

# %%
# @title Plot accuracies
def plot_loss_accuracy(train_acc_list, val_acc_list):
  epochs = len(train_acc_list)

  plt.plot(list(range(epochs)), train_acc_list, label='Training Accuracy', linestyle="--")
  plt.plot(list(range(epochs)), val_acc_list, label='Validation Accuracy')

  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.title('Epoch vs Accuracy')
  plt.legend()
  plt.show()


plot_loss_accuracy(train_acc_list, val_acc_list)

# %%
# @title Save model

outfile_name = path + 'vgg16_{}-real_{}.pt'.format(transform, params)

# save model path
torch.save(model_ft.state_dict(), outfile_name)
