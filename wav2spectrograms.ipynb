# %% [markdown]
# <a href="https://colab.research.google.com/github/smhall97/hallucinating_GANs/blob/main/wav2spectrograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install dependencies
# !sudo apt-get install -y ffmpeg --quiet
# !pip install torchaudio --quiet
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
import torch
#import torch.nn as nn
import torchaudio
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt
#from IPython.display import display, Audio
import librosa
#import librosa.display
import os
import pickle
from tqdm import tqdm

#print(torch.__version__)
print(torchaudio.__version__)

#Import the Google Drive
from google.colab import drive
drive.mount('/content/drive') #it will ask you for a verification code

data_path = '/content/drive/MyDrive/HallucinatingGANs/Code/data/'
# Out:
# 0.9.0
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
n_fft = 1024
#n_mels = 128
win_length = None
hop_length = 256 # smaller hop size leads to better reconstruction but takes longer to compute
#power = 2.0 # squared power spectrogram

get_spectro = torchaudio.transforms.Spectrogram(
    n_fft=n_fft,
    win_length=win_length,
    hop_length=hop_length,
    center=True,
    pad_mode="reflect",
    power=None,
    return_complex=False
)

# %%
def scale_minmax(X, min=0.0, max=1.0):
    X_std = (X - X.min()) / (X.max() - X.min())
    return X_scaled

OVERWRITE = True
TEST_RUN = False # test to see output, only write first file of each genre
test_dir = 'spectrograms_test' # directory to write test outputs
output_dir = 'spectrograms' # directory to write test outputs

src_path = data_path + 'genres/'

if TEST_RUN:
    dst_path = os.path.join(os.path.abspath(data_path), test_dir)
else:
    dst_path = os.path.join(os.path.abspath(data_path), output_dir)

print("Test Run: ", TEST_RUN)
print("Source path: ", src_path)
print("Dest path: ", dst_path)

if not os.path.exists(dst_path):
    os.mkdir(dst_path)

for genre in tqdm(os.listdir(src_path)):

    current_src_dir = os.path.join(src_path, genre)
    current_dst_dir = os.path.join(dst_path, genre)

    if not os.path.isdir(current_src_dir):
      continue
       
    print("Genre: ", genre)

    if not os.path.exists(current_dst_dir):
        os.mkdir(current_dst_dir)
    for i, wav_filename in enumerate(os.listdir(current_src_dir)):
                
        if TEST_RUN and i != 0:
            continue

        pkl_filename = os.path.splitext(wav_filename)[0] + '.pkl'
        src_file = os.path.join(current_src_dir, wav_filename)
        dst_file = os.path.join(current_dst_dir, pkl_filename)
                
        if not OVERWRITE and os.path.exists(dst_file) and not TEST_RUN:
            print("Skipping existing file ", dst_file)
            continue
            
        # 1. load wav file
        wave, sr = librosa.load(src_file, mono=True)
        
        
        # 2. generate squared power spectrogram
        # TODO: is squared power necessary? converting to uint8 already loses a lot of nuance
 #       spectro = librosa.stft(
 #           wave,
 #           n_fft=n_fft,
 #           hop_length=hop_length,
 #           win_length=win_length,
 #       )#**2 remove for now...

        wave = torch.unsqueeze(torch.Tensor(wave),0)
        spectro = get_spectro(wave)
        print(f"spec1 shape: {spectro.shape}  dtype: {spectro.dtype}")
                        
        # normalize to 0-1 range
        # spectro = scale_minmax(spectro)

        # 3. save as pickle file
        print('writing file: ' + dst_file)
        with open(dst_file, 'wb') as f:
            pickle.dump(spectro, f, pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# Test Run:  False
# Source path:  /content/drive/MyDrive/HallucinatingGANs/Code/data/genres/
# Dest path:  /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms
# Genre:  rock
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00009.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00004.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00010.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00000.pkl
# /usr/local/lib/python3.7/dist-packages/torchaudio/functional/functional.py:89: UserWarning: The use of pseudo complex type in spectrogram is now deprecated.Please migrate to native complex type by providing `return_complex=True`. Please refer to https://github.com/pytorch/audio/issues/1337 for more details about torchaudio's plan to migrate to native complex type.
#   "The use of pseudo complex type in spectrogram is now deprecated."
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00002.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00003.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00011.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00008.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00006.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00007.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00001.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00012.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00005.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00025.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00015.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00014.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00021.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00017.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00026.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00016.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00022.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00028.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00033.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00018.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00029.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00013.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00030.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00031.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00023.pkl
# spec1 shape: torch.Size([1, 513, 2586, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.00024.pkl
# spec1 shape: torch.Size([1, 513, 2619, 2])  dtype: torch.float32
# writing file: /content/drive/MyDrive/HallucinatingGANs/Code/data/spectrograms/rock/rock.